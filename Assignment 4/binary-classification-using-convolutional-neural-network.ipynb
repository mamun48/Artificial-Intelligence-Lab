# %% [markdown]
# ### Importing the Libraries

# %%
import os, cv2, random
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Model

# %% [markdown]
# ### Reading the Training Dataset

# %%
directory = "./Training Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_train = []
y_train = []

for image, label in dataset:
    x_train.append(image)
    y_train.append(label)

x_train = np.array(x_train)
y_train = np.array(y_train)

# %% [markdown]
# ### Reading the Validation Dataset

# %%
directory = "./Validation Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_val = []
y_val = []

for image, label in dataset:
    x_val.append(image)
    y_val.append(label)

x_val = np.array(x_val)
y_val = np.array(y_val)

# %% [markdown]
# ### Reading the Test Dataset

# %%
directory = "./Test Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_test = []
y_test = []

for image, label in dataset:
    x_test.append(image)
    y_test.append(label)

x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# ### Function for Generating Label

# %%
def get_label(label):
    if not label:
        return "Grape"
    return "Raisin"

# %% [markdown]
# ### Displaying some samples

# %%
plt.figure(figsize = (13, 13))
for k in range(1, 10):
    plt.subplot(3, 3, k)
    plt.imshow(cv2.cvtColor(x_train[k], cv2.COLOR_BGR2RGB))
    plt.title(get_label(y_train[k]))
    plt.axis("off")

plt.suptitle("Sample Images from Dataset")
plt.show()

# %% [markdown]
# ### Showing Training, Validation & Test Set Shape

# %%
print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_val.shape, y_val.shape)
print("Test set:", x_test.shape, y_test.shape)
# Out:
# Training set: (1070, 32, 32, 3) (1070,)
# Validation set: (260, 32, 32, 3) (260,)
# Test set: (420, 32, 32, 3) (420,)

# %% [markdown]
# ### Building the Model

# %%
inputs = Input(shape = (32, 32, 3))
x = Conv2D(64, (3, 3), activation = "relu")(inputs)
x = Conv2D(64, (3, 3), activation = "relu")(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation = "relu")(x)
x = Conv2D(64, (3, 3), activation = "relu")(x)
x = Conv2D(64, (3, 3), activation = "relu")(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation = "relu")(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(512, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(128, activation = "relu")(x)
outputs = Dense(1, activation = "sigmoid")(x)

model = Model(inputs = inputs, outputs = outputs)

model.compile(optimizer = Adam(0.0001), loss = "binary_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_42 (Conv2D)          (None, 30, 30, 64)        1792
#
#  conv2d_43 (Conv2D)          (None, 28, 28, 64)        36928
#
#  max_pooling2d_21 (MaxPooli  (None, 14, 14, 64)        0
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 12, 12, 64)        36928
#
#  conv2d_45 (Conv2D)          (None, 10, 10, 64)        36928
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 64)          36928
#
#  max_pooling2d_22 (MaxPooli  (None, 4, 4, 64)          0
#  ng2D)
#
#  conv2d_47 (Conv2D)          (None, 2, 2, 32)          18464
#
#  max_pooling2d_23 (MaxPooli  (None, 1, 1, 32)          0
#  ng2D)
#
#  flatten_7 (Flatten)         (None, 32)                0
#
#  dense_28 (Dense)            (None, 512)               16896
#
#  dense_29 (Dense)            (None, 256)               131328
#
#  dense_30 (Dense)            (None, 128)               32896
#
#  dense_31 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 349217 (1.33 MB)
# Trainable params: 349217 (1.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs = 50, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 34/34 [==============================] - 6s 98ms/step - loss: 0.5303 - accuracy: 0.7439 - val_loss: 0.2549 - val_accuracy: 0.9385
# Epoch 2/50
# 34/34 [==============================] - 4s 127ms/step - loss: 0.1303 - accuracy: 0.9636 - val_loss: 0.0873 - val_accuracy: 0.9731
# Epoch 3/50
# 34/34 [==============================] - 4s 116ms/step - loss: 0.1098 - accuracy: 0.9542 - val_loss: 0.0364 - val_accuracy: 0.9885
# Epoch 4/50
# 34/34 [==============================] - 3s 83ms/step - loss: 0.0598 - accuracy: 0.9766 - val_loss: 0.0831 - val_accuracy: 0.9731
# Epoch 5/50
# 34/34 [==============================] - 3s 84ms/step - loss: 0.0108 - accuracy: 0.9981 - val_loss: 0.0809 - val_accuracy: 0.9731
# Epoch 6/50
# 34/34 [==============================] - 3s 96ms/step - loss: 0.0049 - accuracy: 0.9991 - val_loss: 0.1012 - val_accuracy: 0.9731
# Epoch 7/50
# 34/34 [==============================] - 3s 81ms/step - loss: 0.0110 - accuracy: 0.9972 - val_loss: 0.0556 - val_accuracy: 0.9846
# Epoch 8/50
# 34/34 [==============================] - 3s 81ms/step - loss: 0.0292 - accuracy: 0.9897 - val_loss: 0.1064 - val_accuracy: 0.9731
# Epoch 9/50
# 34/34 [==============================] - 3s 79ms/step - loss: 0.0090 - accuracy: 0.9981 - val_loss: 0.0709 - val_accuracy: 0.9808
# Epoch 10/50
# 34/34 [==============================] - 3s 82ms/step - loss: 9.7804e-04 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9769
# Epoch 11/50
# 34/34 [==============================] - 3s 83ms/step - loss: 6.0058e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9808
# Epoch 12/50
# 34/34 [==============================] - 3s 87ms/step - loss: 3.8981e-04 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9808
# Epoch 13/50
# 34/34 [==============================] - 4s 105ms/step - loss: 3.0980e-04 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9846
# Epoch 14/50
# 34/34 [==============================] - 3s 88ms/step - loss: 2.3828e-04 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9846
# Epoch 15/50
# 34/34 [==============================] - 3s 81ms/step - loss: 1.7296e-04 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9846
# Epoch 16/50
# 34/34 [==============================] - 3s 90ms/step - loss: 1.4337e-04 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 0.9846
# Epoch 17/50
# 34/34 [==============================] - 3s 83ms/step - loss: 1.2149e-04 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9808
# Epoch 18/50
# 34/34 [==============================] - 3s 87ms/step - loss: 9.8997e-05 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 0.9808
# Epoch 19/50
# 34/34 [==============================] - 3s 98ms/step - loss: 8.2918e-05 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9808
# Epoch 20/50
# 34/34 [==============================] - 4s 119ms/step - loss: 7.0981e-05 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9808
# Epoch 21/50
# 34/34 [==============================] - 3s 103ms/step - loss: 6.1077e-05 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9808
# Epoch 22/50
# 34/34 [==============================] - 4s 108ms/step - loss: 5.3126e-05 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9808
# Epoch 23/50
# 34/34 [==============================] - 4s 106ms/step - loss: 4.6031e-05 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9808
# Epoch 24/50
# 34/34 [==============================] - 3s 91ms/step - loss: 4.0602e-05 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 0.9808
# Epoch 25/50
# 34/34 [==============================] - 3s 84ms/step - loss: 3.5159e-05 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9808
# Epoch 26/50
# 34/34 [==============================] - 3s 90ms/step - loss: 3.1141e-05 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9808
# Epoch 27/50
# 34/34 [==============================] - 3s 84ms/step - loss: 2.8453e-05 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 0.9808
# Epoch 28/50
# 34/34 [==============================] - 3s 89ms/step - loss: 2.5418e-05 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9808
# Epoch 29/50
# 34/34 [==============================] - 3s 85ms/step - loss: 2.2224e-05 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9808
# Epoch 30/50
# 34/34 [==============================] - 3s 80ms/step - loss: 2.0002e-05 - accuracy: 1.0000 - val_loss: 0.1044 - val_accuracy: 0.9808
# Epoch 31/50
# 34/34 [==============================] - 3s 84ms/step - loss: 1.7969e-05 - accuracy: 1.0000 - val_loss: 0.1069 - val_accuracy: 0.9808
# Epoch 32/50
# 34/34 [==============================] - 3s 77ms/step - loss: 1.6402e-05 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9808
# Epoch 33/50
# 34/34 [==============================] - 3s 84ms/step - loss: 1.5004e-05 - accuracy: 1.0000 - val_loss: 0.1118 - val_accuracy: 0.9808
# Epoch 34/50
# 34/34 [==============================] - 3s 91ms/step - loss: 1.3404e-05 - accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9808
# Epoch 35/50
# 34/34 [==============================] - 3s 84ms/step - loss: 1.2377e-05 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 0.9808
# Epoch 36/50
# 34/34 [==============================] - 3s 90ms/step - loss: 1.1366e-05 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9808
# Epoch 37/50
# 34/34 [==============================] - 3s 79ms/step - loss: 1.0319e-05 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 0.9808
# Epoch 38/50
# 34/34 [==============================] - 3s 83ms/step - loss: 9.3665e-06 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 0.9808
# Epoch 39/50
# 34/34 [==============================] - 3s 80ms/step - loss: 8.5730e-06 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9808
# Epoch 40/50
# 34/34 [==============================] - 3s 83ms/step - loss: 7.8118e-06 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9808
# Epoch 41/50
# 34/34 [==============================] - 3s 80ms/step - loss: 7.0946e-06 - accuracy: 1.0000 - val_loss: 0.1248 - val_accuracy: 0.9808
# Epoch 42/50
# 34/34 [==============================] - 3s 80ms/step - loss: 6.6273e-06 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 0.9808
# Epoch 43/50
# 34/34 [==============================] - 3s 87ms/step - loss: 6.0881e-06 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.9808
# Epoch 44/50
# 34/34 [==============================] - 3s 79ms/step - loss: 5.6111e-06 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 0.9808
# Epoch 45/50
# 34/34 [==============================] - 3s 79ms/step - loss: 5.1789e-06 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 0.9808
# Epoch 46/50
# 34/34 [==============================] - 3s 81ms/step - loss: 4.7232e-06 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 0.9808
# Epoch 47/50
# 34/34 [==============================] - 3s 79ms/step - loss: 4.5191e-06 - accuracy: 1.0000 - val_loss: 0.1308 - val_accuracy: 0.9808
# Epoch 48/50
# 34/34 [==============================] - 3s 77ms/step - loss: 4.0230e-06 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9808
# Epoch 49/50
# 34/34 [==============================] - 3s 76ms/step - loss: 3.7069e-06 - accuracy: 1.0000 - val_loss: 0.1346 - val_accuracy: 0.9808
# Epoch 50/50
# 34/34 [==============================] - 3s 80ms/step - loss: 3.3972e-06 - accuracy: 1.0000 - val_loss: 0.1386 - val_accuracy: 0.9808

# %% [markdown]
# ### Plotting The Accuracy & Loss Graph

# %%
plt.figure(figsize = (17, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label = "Accuracy")
plt.plot(history.history["val_accuracy"], label = "Validation Accuracy")
plt.title("Training & Validation Accuracy", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel("Epochs", fontsize = 16)
plt.ylabel("Accuracy", fontsize = 16)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label = "Loss")
plt.plot(history.history["val_loss"], label = "Validation Loss")
plt.title("Training & Validation Loss", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel("Epochs", fontsize = 16)
plt.ylabel("Loss", fontsize = 16)
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluating the Model on Test Set

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# 14/14 [==============================] - 0s 18ms/step - loss: 1.6104 - accuracy: 0.8214
# Test Accuracy: 82.14%
