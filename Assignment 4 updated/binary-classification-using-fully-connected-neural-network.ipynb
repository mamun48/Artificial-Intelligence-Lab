# %% [markdown]
# ### Importing the Libraries

# %%
import os, cv2, random
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Model

# %% [markdown]
# ### Reading the Training Dataset

# %%
directory = "./Training Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_train = []
y_train = []

for image, label in dataset:
    x_train.append(image)
    y_train.append(label)

x_train = np.array(x_train)
y_train = np.array(y_train)

# %% [markdown]
# ### Reading the Validation Dataset

# %%
directory = "./Validation Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_val = []
y_val = []

for image, label in dataset:
    x_val.append(image)
    y_val.append(label)

x_val = np.array(x_val)
y_val = np.array(y_val)

# %% [markdown]
# ### Reading the Test Dataset

# %%
directory = "./Test Dataset"
categories = ["Grape", "Raisin"]

dataset = []
for category in categories:
    folder = os.path.join(directory, category)
    label = categories.index(category)

    for name in os.listdir(folder):
        image_name = os.path.join(folder, name)
        image = cv2.imread(image_name)
        dataset.append([image, label])

random.shuffle(dataset)

x_test = []
y_test = []

for image, label in dataset:
    x_test.append(image)
    y_test.append(label)

x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# ### Function for Generating Label

# %%
def get_label(label):
    if not label:
        return "Grape"
    return "Raisin"

# %% [markdown]
# ### Displaying some samples

# %%
plt.figure(figsize = (13, 13))
for k in range(1, 10):
    plt.subplot(3, 3, k)
    plt.imshow(cv2.cvtColor(x_train[k], cv2.COLOR_BGR2RGB))
    plt.title(get_label(y_train[k]))
    plt.axis("off")

plt.suptitle("Sample Images from Dataset")
plt.show()

# %% [markdown]
# ### Showing the Train, Validation & Test Set Shape

# %%
print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_val.shape, y_val.shape)
print("Test set:", x_test.shape, y_test.shape)
# Out:
# Training set: (1070, 32, 32, 3) (1070,)
# Validation set: (260, 32, 32, 3) (260,)
# Test set: (420, 32, 32, 3) (420,)

# %% [markdown]
# ### Building the Model

# %%
inputs = Input(shape = (32, 32, 3))
x = Flatten()(inputs)

x = Dense(128, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(512, activation = "relu")(x)
x = Dense(256, activation = "relu")(x)
x = Dense(128, activation = "relu")(x)

outputs = Dense(1, activation = "sigmoid")(x)

model = Model(inputs = inputs, outputs = outputs)

model.compile(optimizer = Adam(0.00001), loss = "binary_crossentropy", metrics = ["accuracy"])
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  flatten_4 (Flatten)         (None, 3072)              0
#
#  dense_24 (Dense)            (None, 128)               393344
#
#  dense_25 (Dense)            (None, 256)               33024
#
#  dense_26 (Dense)            (None, 512)               131584
#
#  dense_27 (Dense)            (None, 256)               131328
#
#  dense_28 (Dense)            (None, 128)               32896
#
#  dense_29 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 722305 (2.76 MB)
# Trainable params: 722305 (2.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs = 50, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 34/34 [==============================] - 3s 20ms/step - loss: 10.7626 - accuracy: 0.5336 - val_loss: 2.4362 - val_accuracy: 0.5731
# Epoch 2/50
# 34/34 [==============================] - 0s 13ms/step - loss: 1.8145 - accuracy: 0.6374 - val_loss: 1.3471 - val_accuracy: 0.6462
# Epoch 3/50
# 34/34 [==============================] - 0s 11ms/step - loss: 1.0230 - accuracy: 0.7234 - val_loss: 1.1911 - val_accuracy: 0.6923
# Epoch 4/50
# 34/34 [==============================] - 0s 13ms/step - loss: 0.6835 - accuracy: 0.7720 - val_loss: 0.9016 - val_accuracy: 0.7423
# Epoch 5/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.4762 - accuracy: 0.8234 - val_loss: 0.8239 - val_accuracy: 0.7577
# Epoch 6/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.3718 - accuracy: 0.8692 - val_loss: 0.7771 - val_accuracy: 0.7692
# Epoch 7/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.2902 - accuracy: 0.8916 - val_loss: 0.7618 - val_accuracy: 0.7731
# Epoch 8/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.2985 - accuracy: 0.8879 - val_loss: 0.7953 - val_accuracy: 0.7808
# Epoch 9/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.2071 - accuracy: 0.9243 - val_loss: 0.7211 - val_accuracy: 0.8038
# Epoch 10/50
# 34/34 [==============================] - 0s 12ms/step - loss: 0.1942 - accuracy: 0.9262 - val_loss: 0.7096 - val_accuracy: 0.7885
# Epoch 11/50
# 34/34 [==============================] - 0s 13ms/step - loss: 0.1673 - accuracy: 0.9299 - val_loss: 0.7259 - val_accuracy: 0.7923
# Epoch 12/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.1702 - accuracy: 0.9308 - val_loss: 0.6373 - val_accuracy: 0.8154
# Epoch 13/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.1170 - accuracy: 0.9598 - val_loss: 0.6848 - val_accuracy: 0.8000
# Epoch 14/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.1307 - accuracy: 0.9486 - val_loss: 0.5821 - val_accuracy: 0.8269
# Epoch 15/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.1035 - accuracy: 0.9626 - val_loss: 0.5449 - val_accuracy: 0.8231
# Epoch 16/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0855 - accuracy: 0.9720 - val_loss: 0.5374 - val_accuracy: 0.8423
# Epoch 17/50
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0763 - accuracy: 0.9757 - val_loss: 0.5238 - val_accuracy: 0.8385
# Epoch 18/50
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0777 - accuracy: 0.9720 - val_loss: 0.5145 - val_accuracy: 0.8423
# Epoch 19/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0652 - accuracy: 0.9822 - val_loss: 0.5010 - val_accuracy: 0.8385
# Epoch 20/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0706 - accuracy: 0.9766 - val_loss: 0.5336 - val_accuracy: 0.8192
# Epoch 21/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0803 - accuracy: 0.9710 - val_loss: 0.5126 - val_accuracy: 0.8385
# Epoch 22/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0585 - accuracy: 0.9832 - val_loss: 0.5689 - val_accuracy: 0.8346
# Epoch 23/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0602 - accuracy: 0.9822 - val_loss: 0.4503 - val_accuracy: 0.8654
# Epoch 24/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0444 - accuracy: 0.9907 - val_loss: 0.4690 - val_accuracy: 0.8462
# Epoch 25/50
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0510 - accuracy: 0.9850 - val_loss: 0.4647 - val_accuracy: 0.8538
# Epoch 26/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0446 - accuracy: 0.9869 - val_loss: 0.5395 - val_accuracy: 0.8462
# Epoch 27/50
# 34/34 [==============================] - 0s 12ms/step - loss: 0.0517 - accuracy: 0.9860 - val_loss: 0.4560 - val_accuracy: 0.8577
# Epoch 28/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0341 - accuracy: 0.9935 - val_loss: 0.4371 - val_accuracy: 0.8769
# Epoch 29/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0575 - accuracy: 0.9822 - val_loss: 0.5037 - val_accuracy: 0.8577
# Epoch 30/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0397 - accuracy: 0.9888 - val_loss: 0.4420 - val_accuracy: 0.8692
# Epoch 31/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0355 - accuracy: 0.9944 - val_loss: 0.4158 - val_accuracy: 0.8731
# Epoch 32/50
# 34/34 [==============================] - 0s 14ms/step - loss: 0.0337 - accuracy: 0.9944 - val_loss: 0.4242 - val_accuracy: 0.8731
# Epoch 33/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0288 - accuracy: 0.9953 - val_loss: 0.4227 - val_accuracy: 0.8731
# Epoch 34/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0257 - accuracy: 0.9963 - val_loss: 0.4125 - val_accuracy: 0.8808
# Epoch 35/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0201 - accuracy: 0.9991 - val_loss: 0.4304 - val_accuracy: 0.8808
# Epoch 36/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0205 - accuracy: 0.9991 - val_loss: 0.4137 - val_accuracy: 0.8808
# Epoch 37/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0234 - accuracy: 0.9963 - val_loss: 0.4270 - val_accuracy: 0.8846
# Epoch 38/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0185 - accuracy: 0.9991 - val_loss: 0.4162 - val_accuracy: 0.8846
# Epoch 39/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0173 - accuracy: 0.9991 - val_loss: 0.4005 - val_accuracy: 0.8769
# Epoch 40/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0190 - accuracy: 0.9981 - val_loss: 0.4184 - val_accuracy: 0.8846
# Epoch 41/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.3989 - val_accuracy: 0.8846
# Epoch 42/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.4003 - val_accuracy: 0.8808
# Epoch 43/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4118 - val_accuracy: 0.8885
# Epoch 44/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0274 - accuracy: 0.9963 - val_loss: 0.3989 - val_accuracy: 0.8885
# Epoch 45/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0155 - accuracy: 0.9991 - val_loss: 0.3799 - val_accuracy: 0.8769
# Epoch 46/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.3976 - val_accuracy: 0.8962
# Epoch 47/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0135 - accuracy: 0.9981 - val_loss: 0.3904 - val_accuracy: 0.8731
# Epoch 48/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0142 - accuracy: 0.9991 - val_loss: 0.4247 - val_accuracy: 0.8923
# Epoch 49/50
# 34/34 [==============================] - 0s 11ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.3895 - val_accuracy: 0.8731
# Epoch 50/50
# 34/34 [==============================] - 0s 10ms/step - loss: 0.0143 - accuracy: 0.9981 - val_loss: 0.3871 - val_accuracy: 0.8846

# %% [markdown]
# ### Plotting The Accuracy & Loss Graph

# %%
plt.figure(figsize = (17, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label = "Accuracy")
plt.plot(history.history["val_accuracy"], label = "Validation Accuracy")
plt.title("Training & Validation Accuracy", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel("Epochs", fontsize = 16)
plt.ylabel("Accuracy", fontsize = 16)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label = "Loss")
plt.plot(history.history["val_loss"], label = "Validation Loss")
plt.title("Training & Validation Loss", fontsize = 16)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel("Epochs", fontsize = 16)
plt.ylabel("Loss", fontsize = 16)
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluating the Model on Test Set

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f"Test Accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# 14/14 [==============================] - 0s 4ms/step - loss: 1.7210 - accuracy: 0.7452
# Test Accuracy: 74.52%
